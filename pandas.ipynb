# %% [markdown]
# ## EVALUACIÓN 3: MODULO 2, SPRINT 1

# %% [markdown]
# ### EJERCICIOS DE PANDAS

# %%
# importamos las librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None

# %% [markdown]
# 1- Exploración del conjunto de datos:
#
# Cargad el fichero, al cargarlo os aparecerá una columna llamada "Unnamed: 0". Cargad el dataset sin que aparezca esta columna. Además realizad un análisis exploratorio que incluya:
# - Cuando leais el fichero, veremos que no podemos ver todas las columnas, utilizad el comando correcto para poder visualizarlas todas.

# %%
# cargamos el fichero en un DataFrame
df = pd.read_csv('data/Spotify_Youtube.csv', index_col = 0)

# %% [markdown]
# - Primeras 5 filas del dataframe

# %%
# mostramos las primeras 5 filas
df.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri Danceability Energy   Key Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705   6,0   -6,679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG        0,676  0,703   8,0   -5,815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU        0,695  0,923   1,0    -3,93
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3        0,689  0,739   2,0    -5,81
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT        0,663  0,694  10,0   -8,627
#
#   Speechiness Acousticness Instrumentalness  Liveness  Valence    Tempo  \
# 0       0,177      0,00836          0,00233    0.6130    0.772  138.559
# 1      0,0302       0,0869         0,000687    0.0463    0.852   92.761
# 2      0,0522       0,0425           0,0469    0.1160    0.551  108.014
# 3       0,026     1,51e-05            0,509    0.0640    0.578  120.423
# 4       0,171       0,0253              0,0    0.0698    0.525  167.953
#
#    Duration_ms                                  Url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   Licensed Official_video        Stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08

# %% [markdown]
# - Últimas 5 filas del dataframe

# %%
# y las 5 últimas
df.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri Danceability Energy  \
# 20713     single  spotify:track:0RtcKQGyI4hr8FgFH1TuYG        0,582  0,926
# 20714     single  spotify:track:3rHvPA8lUnPBkaLyPOc0VV        0,531  0,936
# 20715     single  spotify:track:4jk00YxPtPbhvHJE9N4ddv        0,443   0,83
# 20716     single  spotify:track:5EyErbpsugWliX006eTDex        0,417  0,767
# 20717     single  spotify:track:6lOn0jz1QpjcWeXo1oMm0k        0,498  0,938
#
#        Key Loudness Speechiness Acousticness Instrumentalness  Liveness  \
# 20713  5,0   -6,344      0,0328        0,448              0,0    0.0839
# 20714  4,0   -1,786       0,137        0,028              0,0    0.0923
# 20715  4,0   -4,679      0,0647       0,0243              0,0    0.1540
# 20716  9,0   -4,004       0,419        0,356           0,0184    0.1080
# 20717  6,0   -4,543       0,107      0,00277            0,911    0.1360
#
#        Valence    Tempo  Duration_ms  \
# 20713   0.6580   90.002      94667.0
# 20714   0.6570  174.869     150857.0
# 20715   0.4190  168.388     136842.0
# 20716   0.5390  155.378     108387.0
# 20717   0.0787  160.067     181500.0
#
#                                        Url_youtube  \
# 20713  https://www.youtube.com/watch?v=5SHmKFKlNqI
# 20714  https://www.youtube.com/watch?v=ocTH6KxllDQ
# 20715  https://www.youtube.com/watch?v=5wFhE-HY0hg
# 20716  https://www.youtube.com/watch?v=VMFLbFRNCn0
# 20717  https://www.youtube.com/watch?v=zau0dckCFi0
#
#                                 Title              Channel     Views   Likes  \
# 20713            JUST DANCE HARDSTYLE  SICK LEGEND - Topic   71678.0  1113.0
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic  164741.0  2019.0
# 20715       OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic   35646.0   329.0
# 20716             ONLY GIRL HARDSTYLE  SICK LEGEND - Topic    6533.0    88.0
# 20717              MISS YOU HARDSTYLE  SICK LEGEND - Topic  158697.0  2484.0
#
#        Comments                                        Description Licensed  \
# 20713       0.0  Provided to YouTube by Routenote\n\nJUST DANCE...     True
# 20714       0.0  Provided to YouTube by Routenote\n\nSET FIRE T...     True
# 20715       0.0  Provided to YouTube by Routenote\n\nOUTSIDE HA...     True
# 20716       0.0  Provided to YouTube by Routenote\n\nONLY GIRL ...     True
# 20717       0.0  Provided to YouTube by Routenote\n\nMISS YOU H...     True
#
#       Official_video      Stream
# 20713           True   9227144.0
# 20714           True  10898176.0
# 20715           True   6226110.0
# 20716           True   6873961.0
# 20717           True   5695584.0

# %% [markdown]
# - 10 filas aleatorias del dataframe

# %%
# 10 filas aleatorioas
df.sample(10)
# Out:
#                   Artist                                        Url_spotify  \
# 20408         Fujii Kaze  https://open.spotify.com/artist/6bDWAcdtVR3WHz...
# 4714         Sheryl Crow  https://open.spotify.com/artist/4TKTii6gnOnUXQ...
# 16446                CRO  https://open.spotify.com/artist/3utZ2yeQk0Z3BC...
# 14413  Clayton & Romário  https://open.spotify.com/artist/1tKrZaph4cLsnE...
# 18102         Lil Yachty  https://open.spotify.com/artist/6icQOAFXDZKsum...
# 9612       Gusttavo Lima  https://open.spotify.com/artist/7MiDcPa6UiV3In...
# 14550     Kendrick Lamar  https://open.spotify.com/artist/2YZyLoL8N0Wb9x...
# 186          The Beatles  https://open.spotify.com/artist/3WrFJ7ztbogyGn...
# 2575            Megadeth  https://open.spotify.com/artist/1Yox196W7bzVNZ...
# 11004    Franz Ferdinand  https://open.spotify.com/artist/0XNa1vTidXlvJ2...
#
#                                            Track  \
# 20408                                    Nan-Nan
# 4714   Roll Me Up and Smoke Me When I Die - Live
# 16446                                   so schön
# 14413                     Água Nos Zói - Ao Vivo
# 18102                        running out of time
# 9612                    Saudade Fudida - Ao Vivo
# 14550                        LOVE. FEAT. ZACARI.
# 186                 In My Life - Remastered 2009
# 2575                     Symphony Of Destruction
# 11004                               No You Girls
#
#                                                    Album   Album_type  \
# 20408                               HELP EVER HURT NEVER        album
# 4714                Willie Nelson American Outlaw (Live)  compilation
# 16446                                               trip        album
# 14413                           No Churrasco 2 (Ao Vivo)        album
# 18102                                  Let’s Start Here.        album
# 9612                            Buteco Goiânia (Ao Vivo)        album
# 14550                                              DAMN.        album
# 186                             Rubber Soul (Remastered)        album
# 2575   Countdown To Extinction (Expanded Edition - Re...        album
# 11004                                            Tonight        album
#
#                                         Uri Danceability Energy   Key  \
# 20408  spotify:track:2CbGuO0LtVvbh3umN3mDwM        0,577  0,729   7,0
# 4714   spotify:track:5iis9J2sptrUy0VIpFVIg1        0,427  0,813   0,0
# 16446  spotify:track:1Zz0sHugKITBf0ItiuhmkK        0,673  0,664   0,0
# 14413  spotify:track:2gkKA2pRAsMzbiGPo9gxsc        0,541  0,869   2,0
# 18102  spotify:track:7zy7iE31dGO70ShMXghsfj        0,651   0,72   9,0
# 9612   spotify:track:6QP9bF0ZypxoyQotcgl25J        0,695  0,896   7,0
# 14550  spotify:track:6PGoSes0D9eUDeeAafB2As          0,8  0,585  10,0
# 186    spotify:track:3KfbEIOC7YIv90FIfNSZpo        0,688  0,435   9,0
# 2575   spotify:track:51TG9W3y9qyO8BY5RXKgnZ         0,61  0,891   4,0
# 11004  spotify:track:4VP8QiCeaZq8BeTIUrMQOG        0,677  0,916   2,0
#
#       Loudness Speechiness Acousticness Instrumentalness  Liveness  Valence  \
# 20408   -7,113       0,221        0,394         0,000156    0.1440    0.692
# 4714     -9,02      0,0737       0,0713            0,109    0.8730    0.344
# 16446   -6,838       0,033         0,41         5,45e-05    0.1730    0.649
# 14413   -1,875      0,0601        0,476              0,0    0.8680    0.494
# 18102   -6,529       0,161        0,331            0,413    0.5280    0.705
# 9612    -3,808      0,0716        0,329              0,0    0.9450    0.782
# 14550   -7,343      0,0924        0,264              0,0    0.1530    0.779
# 186    -11,359      0,0323        0,449              0,0    0.1130    0.435
# 2575    -5,452      0,0587     0,000805           0,0928    0.0657    0.510
# 11004   -4,102      0,0296       0,0086         7,68e-05    0.0967    0.878
#
#          Tempo  Duration_ms                                  Url_youtube  \
# 20408  180.065     320640.0  https://www.youtube.com/watch?v=Nt6ZwuVzOS4
# 4714   106.859     134267.0  https://www.youtube.com/watch?v=kn-AB78kvvE
# 16446  125.037     223800.0  https://www.youtube.com/watch?v=w5GaSTnk5iU
# 14413  129.820     188952.0                                          NaN
# 18102   90.024     269245.0  https://www.youtube.com/watch?v=eQRyZE2r7oM
# 9612   163.940     157547.0  https://www.youtube.com/watch?v=HycgJuSa9jo
# 14550  126.058     213400.0  https://www.youtube.com/watch?v=ox7RsX1Ee34
# 186    103.239     146333.0  https://www.youtube.com/watch?v=YBcdt6DsLQA
# 2575   139.903     246733.0  https://www.youtube.com/watch?v=h2LG7JXK5mQ
# 11004  104.780     223787.0  https://www.youtube.com/watch?v=25sBhhOR4lw
#
#                                                    Title  \
# 20408              Fujii Kaze - Nan-Nan (Official Video)
# 4714   Willie Nelson - Roll Me Up and Smoke Me When I...
# 16446                                           so schön
# 14413                                                NaN
# 18102  Lil Yachty - running out of time (Official Audio)
# 9612   Gusttavo Lima - Saudade Fudida (Ao Vivo em Goi...
# 14550                  Kendrick Lamar - LOVE. ft. Zacari
# 186                         In My Life (Remastered 2009)
# 2575   Megadeth - Symphony of Destruction [Official V...
# 11004    Franz Ferdinand - No You Girls (Official Video)
#
#                      Channel        Views      Likes  Comments  \
# 20408             Fujii Kaze   28340727.0   308547.0   16211.0
# 4714        WillieNelsonVEVO    8726132.0    58295.0    1658.0
# 16446            CRO - Topic     273662.0     3869.0      28.0
# 14413                    NaN          NaN        NaN       NaN
# 18102               lil boat     198056.0     6455.0     394.0
# 9612   Gusttavo Lima Oficial   18093137.0    67550.0    1791.0
# 14550      KendrickLamarVEVO  124542486.0  1925485.0   58013.0
# 186      The Beatles - Topic   63223118.0   463315.0    8607.0
# 2575          Rodrigo Schang    7729299.0    69609.0    2215.0
# 11004   Domino Recording Co.   14179727.0    65954.0    2503.0
#
#                                              Description Licensed  \
# 20408  Fujii Kaze - “Nan-Nan” \n\n\n▶︎ Kaze talks abo...    False
# 4714   "Roll Me Up and Smoke Me When I Die” by Willie...     True
# 16446  Provided to YouTube by Universal Music Group\n...     True
# 14413                                                NaN      NaN
# 18102                                                NaN    False
# 9612   Vídeo Oficial de "Saudade Fudida" do Gusttavo ...    False
# 14550  DAMN. available now http://smarturl.it/DAMN \n...     True
# 186    Provided to YouTube by Universal Music Group\n...     True
# 2575   All Copyrights go to their respective owners.\...    False
# 11004  Franz Ferdinand - "No You Girls" from 'Tonight...     True
#
#       Official_video       Stream
# 20408           True   29902635.0
# 4714            True    9999321.0
# 16446           True    6010650.0
# 14413            NaN   85639987.0
# 18102          False    2304270.0
# 9612           False   15878112.0
# 14550           True  969849343.0
# 186             True  266426563.0
# 2575           False  232533442.0
# 11004           True   76187432.0

# %% [markdown]
# - ¿Cuántas filas y columnas tenemos en el dataframe?

# %%
# para conocer el tamaño de nuestro DataFrame podemos utilizar el método .shape
filas, columnas = df.shape
print(f'El dataframe tiene {filas} filas y {columnas} columnas')
# Out:
# El dataframe tiene 20718 filas y 27 columnas

# %% [markdown]
# - ¿Cuáles son los tipos de los datos de cada columna del dataframe?

# %%
# con .info() podemos ver las columnas, la cantidad de datos no nulos en cada una de ellas y el tipo de dato
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  object
#  7   Energy            20716 non-null  object
#  8   Key               20716 non-null  object
#  9   Loudness          20716 non-null  object
#  10  Speechiness       20716 non-null  object
#  11  Acousticness      20716 non-null  object
#  12  Instrumentalness  20716 non-null  object
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
#  16  Duration_ms       20716 non-null  float64
#  17  Url_youtube       20248 non-null  object
#  18  Title             20248 non-null  object
#  19  Channel           20248 non-null  object
#  20  Views             20248 non-null  float64
#  21  Likes             20177 non-null  float64
#  22  Comments          20149 non-null  float64
#  23  Description       19842 non-null  object
#  24  Licensed          20248 non-null  object
#  25  Official_video    20248 non-null  object
#  26  Stream            20142 non-null  float64
# dtypes: float64(8), object(19)
# memory usage: 4.4+ MB

# %% [markdown]
# - ¿Cuántos valores nulos tenemos por columna?

# %%
# con el método .isnull() y sum() combinados podemos comprobar cuantos valores nulos tenemso por cada columna
df.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# Official_video      470
# Stream              576
# dtype: int64

# %%
# haciendo una doble suma podemos comprobar el numero total de nulos de todo el DataFrame
nulos = df.isnull().sum().sum()
print(f'El numero de nulos totales es de {nulos}')
# Out:
# El numero de nulos totales es de 5404

# %% [markdown]
# - ¿Tenemos filas duplicadas en el dataframe?

# %%
# con el metodo .duplicated() podemos hacer lo mismo, sacando en este caso el numero de duplicados
duplicados = df.duplicated().sum()
print(f'El numero de datos duplicados es {duplicados}')
# Out:
# El numero de datos duplicados es 0

# %% [markdown]
# - Muestra los principales estadísticos para las columnas numéricas del dataframe

# %%
df.describe().T
# Out:
#                count          mean           std         min           25%  \
# Liveness     20716.0  1.935210e-01  1.685309e-01      0.0145  9.410000e-02
# Valence      20716.0  5.298533e-01  2.454408e-01      0.0000  3.390000e-01
# Tempo        20716.0  1.206383e+02  2.957902e+01      0.0000  9.700200e+01
# Duration_ms  20716.0  2.247176e+05  1.247905e+05  30985.0000  1.800095e+05
# Views        20248.0  9.393782e+07  2.746443e+08      0.0000  1.826002e+06
# Likes        20177.0  6.633411e+05  1.789324e+06      0.0000  2.158100e+04
# Comments     20149.0  2.751899e+04  1.932347e+05      0.0000  5.090000e+02
# Stream       20142.0  1.359422e+08  2.441321e+08   6574.0000  1.767486e+07
#
#                       50%           75%           max
# Liveness     1.250000e-01  2.370000e-01  1.000000e+00
# Valence      5.370000e-01  7.262500e-01  9.930000e-01
# Tempo        1.199650e+02  1.399350e+02  2.433720e+02
# Duration_ms  2.132845e+05  2.524430e+05  4.676058e+06
# Views        1.450110e+07  7.039975e+07  8.079649e+09
# Likes        1.244810e+05  5.221480e+05  5.078865e+07
# Comments     3.277000e+03  1.436000e+04  1.608314e+07
# Stream       4.968298e+07  1.383581e+08  3.386520e+09

# %% [markdown]
# - Muestra los principales estadísticos para las columnas categóricas del dataframe

# %%
df.describe(include='object').T
# Out:
#                   count unique  \
# Artist            20718   2079
# Url_spotify       20718   2079
# Track             20718  17841
# Album             20718  11937
# Album_type        20718      3
# Uri               20718  18862
# Danceability      20716    898
# Energy            20716   1268
# Key               20716     12
# Loudness          20716   9417
# Speechiness       20716   1303
# Acousticness      20716   3138
# Instrumentalness  20716   4012
# Url_youtube       20248  18154
# Title             20248  18146
# Channel           20248   6714
# Description       19842  17395
# Licensed          20248      2
# Official_video    20248      2
#
#                                                                 top   freq
# Artist                                                     Gorillaz     10
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...     10
# Track                     El Ultimo Adiós - Varios Artistas Version     24
# Album                                                 Greatest Hits     30
# Album_type                                                    album  14926
# Uri                            spotify:track:0tzixmHNQfE6S6SirSToxW     24
# Danceability                                                  0,687     78
# Energy                                                        0,572     60
# Key                                                             0,0   2305
# Loudness                                                     -7,818     25
# Speechiness                                                  0,0324     72
# Acousticness                                                  0,114     50
# Instrumentalness                                                0,0   9391
# Url_youtube             https://www.youtube.com/watch?v=GqOvxbFLwjY     18
# Title             Color Esperanza 2020 - Various Artists (Offici...     18
# Channel                                                    T-Series    238
# Description                                                            114
# Licensed                                                       True  14140
# Official_video                                                 True  15723

# %% [markdown]
# 2- Preparación de los datos:

# %% [markdown]
# - Los nombres de las columnas empiezan con mayúsculas, poned todos los nombres de las columnas en minúsculas.

# %%
df.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'Official_video', 'Stream'],
#       dtype='object')

# %%
columnas_minus = {col:col.lower() for col in df.columns}
df.rename(columns = columnas_minus, inplace = True)

# %%
df.sample(3)
# Out:
#            artist                                        url_spotify  \
# 5162    In Flames  https://open.spotify.com/artist/57ylwQTnFnIhJh...
# 445    Tory Lanez  https://open.spotify.com/artist/2jku7tDXc6XoB6...
# 14218  Chief Keef  https://open.spotify.com/artist/15iVAtD3s3FsQR...
#
#                    track      album   album_type  \
# 5162   Only for the Weak    Clayman        album
# 445            In For It  In For It       single
# 14218       Don't Like.1   G.O.O.D.  compilation
#
#                                         uri danceability energy  key loudness  \
# 5162   spotify:track:0JBQnLKfLXmlkquabLtAgd        0,418  0,835  0,0   -4,824
# 445    spotify:track:6ydWxkzjDktHsTzvWcaZ1i        0,383  0,531  5,0   -7,814
# 14218  spotify:track:3YqJ0iaDWM0aqEDQExd2j3        0,657  0,611  6,0   -5,415
#
#       speechiness acousticness instrumentalness  liveness  valence    tempo  \
# 5162       0,0449     2,33e-06            0,766     0.289   0.5490  104.986
# 445        0,0741       0,0753         0,000102     0.108   0.0375  105.971
# 14218       0,225      0,00937              0,0     0.146   0.6160  132.062
#
#        duration_ms                                  url_youtube  \
# 5162      294867.0  https://www.youtube.com/watch?v=qnLunQEcMn0
# 445       293307.0  https://www.youtube.com/watch?v=x_HEpW9v69A
# 14218     283653.0  https://www.youtube.com/watch?v=6g5ZF6DUrHI
#
#                                                    title        channel  \
# 5162   IN FLAMES - Only For The Weak (OFFICIAL MUSIC ...      In Flames
# 445    Tory Lanez - Sorry 4 What ? // LV BELT (Offici...     Tory Lanez
# 14218  Chief Keef ft. Lil Reese - I Don't Like (Offic...  ChiefKeefVEVO
#
#             views     likes  comments  \
# 5162    3856211.0   32310.0    1072.0
# 445     1516174.0   29277.0    1631.0
# 14218  49665101.0  585399.0   28327.0
#
#                                              description licensed  \
# 5162   Official music video for IN FLAMES "Only For T...     True
# 445    Official VIDEO for "Tory Lanez - Sorry 4 What ...     True
# 14218  Pre Order http://smarturl.it/FinallyRich\n\n\n...     True
#
#       official_video      stream
# 5162            True  78929442.0
# 445             True  76686049.0
# 14218           True         NaN

# %% [markdown]
# - Haciendo el análisis exploratorio nos deberíamos haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness, instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Cread una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.

# %%
def int_a_float(c):
    '''
    Funcion que remplaza las comas por puntos de los datos del dataframe y los convierte a numeros decimales

    Parámetro: cada dato de la columna dada
    Return: el dato convertido a numero decimal
    '''
    try:
        return float(c.replace(',','.'))
    except:
        np.nan

# %%
# una vez definida la funcion, utilizamos .apply() para cada una de las columnas que deseamos cambiar
df['danceability'] = df['danceability'].apply(int_a_float)
df['energy'] = df['energy'].apply(int_a_float)
df['key'] = df['key'].apply(int_a_float)
df['loudness'] = df['loudness'].apply(int_a_float)
df['acousticness'] = df['acousticness'].apply(int_a_float)
df['speechiness'] = df['speechiness'].apply(int_a_float)
df['instrumentalness'] = df['instrumentalness'].apply(int_a_float)

# %%
df.sample()
# Out:
#       artist                                        url_spotify  \
# 15629   MNEK  https://open.spotify.com/artist/7uMh23xWiuR7zs...
#
#                            track                      album album_type  \
# 15629  Head & Heart (feat. MNEK)  Head & Heart (feat. MNEK)     single
#
#                                         uri  danceability  energy  key  \
# 15629  spotify:track:6cx06DFPPHchuUAcTxznu9         0.734   0.874  8.0
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 15629    -3.158       0.0662         0.168          0.000011    0.0489
#
#        valence    tempo  duration_ms  \
# 15629    0.905  122.953     166028.0
#
#                                        url_youtube  \
# 15629  https://www.youtube.com/watch?v=CRuOOxF-ENQ
#
#                                                    title     channel  \
# 15629  Joel Corry x MNEK - Head & Heart [Official Video]  Joel Corry
#
#              views      likes  comments  \
# 15629  254737803.0  1054418.0   20257.0
#
#                                              description licensed  \
# 15629  Joel Corry x MNEK - Head & Heart [Official Vid...     True
#
#       official_video        stream
# 15629           True  1.018441e+09

# %% [markdown]
# - Después de haber hecho los cambios, chequead los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, cread otra función o modificar la anterior para que sean de tipo float.

# %%
# con .info() comprobamos que los cambiso se han realizado correctamente
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            20718 non-null  object
#  1   url_spotify       20718 non-null  object
#  2   track             20718 non-null  object
#  3   album             20718 non-null  object
#  4   album_type        20718 non-null  object
#  5   uri               20718 non-null  object
#  6   danceability      20716 non-null  float64
#  7   energy            20716 non-null  float64
#  8   key               20716 non-null  float64
#  9   loudness          20716 non-null  float64
#  10  speechiness       20716 non-null  float64
#  11  acousticness      20716 non-null  float64
#  12  instrumentalness  20716 non-null  float64
#  13  liveness          20716 non-null  float64
#  14  valence           20716 non-null  float64
#  15  tempo             20716 non-null  float64
#  16  duration_ms       20716 non-null  float64
#  17  url_youtube       20248 non-null  object
#  18  title             20248 non-null  object
#  19  channel           20248 non-null  object
#  20  views             20248 non-null  float64
#  21  likes             20177 non-null  float64
#  22  comments          20149 non-null  float64
#  23  description       19842 non-null  object
#  24  licensed          20248 non-null  object
#  25  official_video    20248 non-null  object
#  26  stream            20142 non-null  float64
# dtypes: float64(15), object(12)
# memory usage: 4.4+ MB

# %% [markdown]
# - Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haced lo mismo para las columnas de "track" y "album".

# %%
df['title'].unique()
# Out:
# array(['Gorillaz - Feel Good Inc. (Official Video)',
#        'Gorillaz - Rhinestone Eyes [Storyboard Film] (Official Music Video)',
#        'Gorillaz - New Gold ft. Tame Impala & Bootie Brown (Official Visualiser)',
#        ..., 'OUTSIDE HARDSTYLE SPED UP', 'ONLY GIRL HARDSTYLE',
#        'MISS YOU HARDSTYLE'], dtype=object)

# %%
def titulos(t):
    '''
    Funcion que unifica el formato de los títulos, poniendo la primera letra de cada palabra 
    en mayúsculas y el resto en minúscula

    Parámetro: cada dato de la columna dada (titulos)
    Return: el titulo en el formato deseado
    '''
    try:
        return t.title()
    except:
        return np.nan

# %%
df['title'] = df['title'].apply(titulos)

# %% [markdown]
# - Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Cread una función que nos elimine este símbolo de los nombres de los artistas.

# %%
# analizamos en qué nombres de artista se encuentra el símbolo erroneo
for n in df['artist']:
    if '$' in n:
        print(n)
# Out:
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Too $hort
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Curren$y
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# Ty Dolla $ign
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Rocky
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# A$AP Ferg
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# Joey Bada$$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# $uicideboy$
# bbno$
# bbno$
# bbno$
# bbno$
# bbno$
# bbno$
# bbno$
# bbno$
# bbno$
# bbno$
# $NOT
# $NOT
# $NOT
# $NOT
# $NOT
# $NOT
# $NOT
# $NOT
# $NOT
# $NOT

# %%
# Vemos que en algunos nombres de artista hay un $ en vez de una S (ej. 'Too $hort'), por lo que creamos una funcion que lleve a cabo dicho cambio
def nombre_artista(a):
    '''
    Funcion que elimina el símbolo $ de los nombres de los artistas

    Parámetro: cada dato de la columna dada (artistas)
    Return: el nombre del artista en el formato deseado   
    '''
    try:
        return a.replace('$','S').title()
    except:
        return np.nan

# %%
df['artist'] = df['artist'].apply(nombre_artista)

# %%
# Comprobamos que los nombres se han cambiado correctamente
df[df['artist'] == 'Currensy'].sample()
# Out:
#          artist                                        url_spotify     track  \
# 10258  Currensy  https://open.spotify.com/artist/6X8WdFjrNhXATM...  All Work
#
#                   album album_type                                   uri  \
# 10258  Back at Burnie’s      album  spotify:track:0GNbF413D1n8yS2vLpOBhl
#
#        danceability  energy  key  loudness  speechiness  acousticness  \
# 10258         0.688    0.88  9.0    -5.044        0.233        0.0564
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 10258               0.0     0.154    0.618  140.904     150047.0
#
#                                        url_youtube  \
# 10258  https://www.youtube.com/watch?v=M57sfGiH8KE
#
#                                                    title              channel  \
# 10258  Curren$Y - All Work (Feat. Young Dolph) [Offic...  Jet Life Recordings
#
#            views    likes  comments  \
# 10258  1785868.0  37681.0    1910.0
#
#                                              description licensed  \
# 10258  #YoungDolph #CurrenSy #BACKATBURNIES\n\nShot &...     True
#
#       official_video      stream
# 10258           True  20050775.0

# %% [markdown]
# 3- Filtrado de datos y Visualización:

# %% [markdown]
# - Filtrado de datos y Visualización:
# ¿Cuáles son los valores únicos de la columna "album_type"? Cread tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
t1, t2, t3 = df['album_type'].unique()
print(f'Los tipos de album son "{t1}", "{t2}" y "{t3}"')
# Out:
# Los tipos de album son "album", "single" y "compilation"

# %%
df_album = df[df['album_type'] == 'album']
df_album.sample(2)
# Out:
#              artist                                        url_spotify  \
# 6973  Sertab Erener  https://open.spotify.com/artist/4W31XN2JH8mC54...
# 8359      Manu Chao  https://open.spotify.com/artist/6wH6iStAh4KIaW...
#
#             track        album album_type  \
# 6973    Mecbursun         Lâ'l      album
# 8359  Clandestino  Clandestino      album
#
#                                        uri  danceability  energy   key  \
# 6973  spotify:track:30P0bhT0Ebfl9Bxua0mzYr         0.682   0.426  10.0
# 8359  spotify:track:51R2M1JgyFfRS3e6v5wCt3         0.680   0.594   6.0
#
#       loudness  speechiness  acousticness  instrumentalness  liveness  \
# 6973   -14.208       0.0993         0.371               0.0    0.0863
# 8359    -6.417       0.0688         0.469               0.0    0.4310
#
#       valence  tempo  duration_ms  \
# 6973    0.922  87.88     233613.0
# 8359    0.774  85.04     149173.0
#
#                                       url_youtube  \
# 6973  https://www.youtube.com/watch?v=5mqjl6_mkcA
# 8359  https://www.youtube.com/watch?v=TyA-oz7lSrc
#
#                                          title     channel      views  \
# 6973                 Sertab Erener - Mecbursun  netd müzik  1161313.0
# 8359  Manu Chao - Clandestino (Official Audio)   Manu Chao  9874131.0
#
#         likes  comments                                        description  \
# 6973   6648.0     198.0  Sertab Erener'in, Garaj Müzik etiketiyle yayın...
# 8359  58378.0     905.0  Manu Chao - Clandestino (Official Audio)\nSubs...
#
#      licensed official_video      stream
# 6973     True           True  27517600.0
# 8359     True           True  70610935.0

# %%
df_single = df[df['album_type'] == 'single']
df_single.sample(2)
# Out:
#                artist                                        url_spotify  \
# 10095  Rekha Bhardwaj  https://open.spotify.com/artist/3cqeO3muWIW5uS...
# 6456               Lx  https://open.spotify.com/artist/10XY9PZCJKzUFz...
#
#                     track               album album_type  \
# 10095  Kabira - VIP Remix  Kabira (VIP Remix)     single
# 6456       Wer von Euch?!      Wer von Euch?!     single
#
#                                         uri  danceability  energy  key  \
# 10095  spotify:track:7cd4cQWYod32lYiISRis0q         0.501   0.621  2.0
# 6456   spotify:track:5T2uDaBN4yg9PNUQ88WVcp         0.852   0.545  8.0
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 10095    -8.771       0.0388         0.186               0.0     0.121
# 6456     -7.039       0.4190         0.511               0.0     0.168
#
#        valence    tempo  duration_ms  \
# 10095    0.483  154.909     219916.0
# 6456     0.657  139.891     140696.0
#
#                                        url_youtube  \
# 10095  https://www.youtube.com/watch?v=XvgM44RFqI8
# 6456   https://www.youtube.com/watch?v=EisHptTaGK0
#
#                              title              channel      views    likes  \
# 10095           Kabira (Vip Remix)  Tochi Raina - Topic     3618.0    111.0
# 6456   Lx X Silva - Wer Von Euch?!             CrhymeTV  1440233.0  35188.0
#
#        comments                                        description licensed  \
# 10095       0.0  Provided to YouTube by Nikita Music\n\nKabira ...     True
# 6456     1873.0  „Wer von Euch?!“ jetzt streamen ► https://umg....     True
#
#       official_video     stream
# 10095           True  2045481.0
# 6456            True  3040822.0

# %%
df_compilation = df[df['album_type'] == 'compilation']
df_compilation.sample(2)
# Out:
#               artist                                        url_spotify  \
# 5464  Inspectah Deck  https://open.spotify.com/artist/4OBbOrkD4geIjO...
# 9301       Ivy Queen  https://open.spotify.com/artist/6p2442ymrT9lZE...
#
#                 track                          album   album_type  \
# 5464     Execute Them  Wu-Tang Killa Bees: The Swarm  compilation
# 9301  los Disicipulos                  12 Discipulos  compilation
#
#                                        uri  danceability  energy  key  \
# 5464  spotify:track:4BtjWAnJUIBV6tX5dnzawL         0.778   0.482  5.0
# 9301  spotify:track:2vWWy37CDlDlfPipzb4iIX         0.629   0.893  1.0
#
#       loudness  speechiness  acousticness  instrumentalness  liveness  \
# 5464    -9.460        0.190         0.571          0.000114     0.202
# 9301    -4.009        0.275         0.181          0.000000     0.115
#
#       valence   tempo  duration_ms  \
# 5464    0.744  96.010     220533.0
# 9301    0.860  94.042     269559.0
#
#                                       url_youtube  \
# 5464  https://www.youtube.com/watch?v=XksqmrjJjac
# 9301                                          NaN
#
#                                  title       channel     views   likes  \
# 5464  Wu-Tang Clan - Execute Them (Hd)  Brooklyn Zoo  230564.0  2250.0
# 9301                               NaN           NaN       NaN     NaN
#
#       comments                                        description licensed  \
# 5464     238.0  Wu-Tang Clan - Execute Them from the album The...    False
# 9301       NaN                                                NaN      NaN
#
#      official_video      stream
# 5464          False   1678827.0
# 9301            NaN  34067509.0

# %% [markdown]
# - Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Mostrad los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordenar los resultados de mayor a menor en base a la media.

# %%
df_danceability = df.groupby('artist')['danceability'].agg(['mean', 'std']).sort_values(by = 'mean', ascending = False )
df_danceability.head(4)
# Out:
#                        mean       std
# artist
# Saweetie             0.8858  0.050918
# Young Dolph          0.8629  0.046596
# Megan Thee Stallion  0.8605  0.091036
# Dave                 0.8591  0.096773

# %%
df_acousticness = df.groupby('artist')['acousticness'].agg(['mean', 'std']).sort_values(by = 'mean', ascending = False )
df_acousticness.sample(4)
# Out:
#                       mean       std
# artist
# Lamb Of God       0.001099  0.001284
# Ricky Montgomery  0.177160  0.136514
# The Kinks         0.309690  0.238023
# Carly Rae Jepsen  0.037234  0.033942

# %%
df_speechiness = df.groupby('artist')['speechiness'].agg(['mean', 'std']).sort_values(by = 'mean', ascending = False )
df_speechiness.sample(4)
# Out:
#                  mean       std
# artist
# Dj Luian      0.10749  0.036398
# John Denver   0.05066  0.043097
# Travis Scott  0.16103  0.131417
# Yoko Ono      0.07904  0.046312

# %% [markdown]
# - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, querremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:

# %% [markdown]
#     - Agrupar por artista y calcular la media de visitas y de likes.

# %%
df.sample()
# Out:
#                artist                                        url_spotify  \
# 17967  Rauw Alejandro  https://open.spotify.com/artist/1mcTU81TzQhprh...
#
#        track             album album_type  \
# 17967  Party  Un Verano Sin Ti      album
#
#                                         uri  danceability  energy  key  \
# 17967  spotify:track:4tYFy8ALRjIZvnvSLw5lxN         0.829   0.799  9.0
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 17967    -5.389       0.0897        0.0151          0.000543     0.242
#
#        valence   tempo  duration_ms  \
# 17967    0.471  97.013     227629.0
#
#                                        url_youtube  \
# 17967  https://www.youtube.com/watch?v=G9XrXnfJPsk
#
#                                                    title    channel  \
# 17967  Bad Bunny (Ft. Rauw Alejandro) - Party (360° V...  Bad Bunny
#
#              views      likes  comments  \
# 17967  110673862.0  1130881.0   16253.0
#
#                                              description licensed  \
# 17967  Bad Bunny (ft. Rauw Alejandro) - Party (360° V...     True
#
#       official_video       stream
# 17967           True  513627219.0

# %%
df_views_likes = df.groupby('artist')[['views', 'likes']].sum()
df_views_likes.sample(3)
# Out:
#                         views       likes
# artist
# Shubh            3.301926e+08   5149479.0
# Migos            3.930334e+09  24882779.0
# Luther Vandross  3.034210e+08   2058174.0

# %% [markdown]
#     - Quedaros con los 10 artistas que más visitas han tenido.

# %%
df_mas_vistos = df_views_likes.sort_values('views', ascending = False).head(10).reset_index()
df_mas_vistos
# Out:
#                     artist         views       likes
# 0               Ed Sheeran  1.546021e+10  83543319.0
# 1                Cocomelon  1.460167e+10  41713913.0
# 2               Katy Perry  1.312063e+10  63067090.0
# 3             Charlie Puth  1.216759e+10  86336925.0
# 4               Luis Fonsi  1.162811e+10  66908489.0
# 5            Justin Bieber  1.099106e+10  78584348.0
# 6             Daddy Yankee  1.087193e+10  65518171.0
# 7               Bruno Mars  1.024092e+10  59616146.0
# 8  Macklemore & Ryan Lewis  1.012206e+10  66041410.0
# 9                 Coldplay  9.997278e+09  63157895.0

# %% [markdown]
#     - Quedaros con los 10 artistas que más likes han tenido.

# %%
df_mas_likes = df_views_likes.sort_values('likes', ascending = False).head(10).reset_index()
df_mas_likes
# Out:
#             artist         views        likes
# 0              Bts  5.607867e+09  139403808.0
# 1        Blackpink  9.392962e+09  132302505.0
# 2     Charlie Puth  1.216759e+10   86336925.0
# 3       Ed Sheeran  1.546021e+10   83543319.0
# 4    Justin Bieber  1.099106e+10   78584348.0
# 5    Billie Eilish  4.821569e+09   73338537.0
# 6  Imagine Dragons  9.093785e+09   72274477.0
# 7      Alan Walker  7.256847e+09   67977702.0
# 8         Dj Snake  9.180268e+09   67775831.0
# 9       Luis Fonsi  1.162811e+10   66908489.0

# %% [markdown]
#     - Haced un subplot, donde en uno tengamos los 10 artistas con más likes y en el otro los 10 artistas con mas views.

# %%
fig,ax = plt.subplots(1,2, figsize = (20,7))

sns.barplot(x = 'artist', y='views', data = df_mas_vistos, ax = ax[0], palette= 'Set2', edgecolor = 'black')
sns.barplot(x = 'artist', y = 'likes', data = df_mas_likes, ax = ax[1], palette= 'Set3', edgecolor = 'black')

ax[0].set_title('10 Artistas más vistos')
ax[1].set_title('10 Artistas con más likes')

ax[0].set_xticklabels(df_mas_vistos['artist'], rotation=90)
ax[1].set_xticklabels(df_mas_likes['artist'], rotation=90)


plt.show()

# %% [markdown]
#     - BONUS Haced lo mismo para los datos de tipo "single".

# %% [markdown]
# - Ahora queremos analizar la colaboración entre artistas en la industria musical, se tienen datos de las colaboraciones realizadas en los últimos años. Se desea conocer cuáles son los artistas que han colaborado en mayor cantidad de canciones y generar un ranking con los diez primeros. ¿Qué artistas con los que más colaboraciones tienen? Para esto tendréis que:

# %% [markdown]
#     - Filtrad los datos para quedaros solo con aquellos datos donde en la columna "track" tengamos "feat".

# %%
# creamos el patron de regex
patron = 'feat'

# %%
df_feat = df[df["track"].str.contains(patron, regex=True)]
df_feat.sample(3)
# Out:
#              artist                                        url_spotify  \
# 10069           Nko  https://open.spotify.com/artist/4kTOsBwxhA2Sn4...
# 12117        1Nonly  https://open.spotify.com/artist/3ZHU5AKrUmIPnC...
# 8410   Nile Rodgers  https://open.spotify.com/artist/3yDIp0kaq9EFKe...
#
#                                                    track  \
# 10069                           DRILLMOON (feat. thasup)
# 12117             Come Thru (feat. Shady Moon & Ciscaux)
# 8410   Miami (Öwnboss Extended Remix) [feat. Nile Rod...
#
#                                             album album_type  \
# 10069                               TRENCHES BABY      album
# 12117      Come Thru (feat. Shady Moon & Ciscaux)     single
# 8410   Miami (Öwnboss Remix) [feat. Nile Rodgers]     single
#
#                                         uri  danceability  energy  key  \
# 10069  spotify:track:6Y2Z4GgQaDD31T9HLBtpD2         0.579   0.592  1.0
# 12117  spotify:track:7zjO4Hy7TjwyGTJmOwaYJs         0.839   0.611  6.0
# 8410   spotify:track:3lUJNlIFgP9lvunZIqgZH3         0.783   0.847  1.0
#
#        loudness  speechiness  acousticness  instrumentalness  liveness  \
# 10069    -5.842       0.0558       0.31000          0.000000    0.1300
# 12117    -8.748       0.2790       0.07370          0.000013    0.0922
# 8410     -5.922       0.0493       0.00769          0.013600    0.0358
#
#        valence    tempo  duration_ms  \
# 10069    0.409  140.067     210000.0
# 12117    0.646  129.978     148615.0
# 8410     0.647  124.989     225600.0
#
#                                        url_youtube  \
# 10069  https://www.youtube.com/watch?v=80Mcb3w6OYQ
# 12117  https://www.youtube.com/watch?v=7PQqXgBiWvY
# 8410   https://www.youtube.com/watch?v=EPn9yoN1g2U
#
#                                                    title  \
# 10069  Rondo X Drillmoon Feat. Thasup (Official Visua...
# 12117  Come Thru (Ft. Shady Moon & Ciscaux) [Prod. Du...
# 8410   Miami (Öwnboss Extended Remix) (Feat. Nile Rod...
#
#                     channel      views    likes  comments  \
# 10069           Rondodasosa   747001.0  15565.0     619.0
# 12117                1nonly  1373425.0  50510.0    1810.0
# 8410   Lola Audreys - Topic      991.0     31.0       0.0
#
#                                              description licensed  \
# 10069  Listen to my first album TRENCHES BABY: https:...     True
# 12117  hope yall fw this:) blow this up!\n\nsong link...     True
# 8410   Provided to YouTube by Foundation Media LLC\n\...     True
#
#       official_video      stream
# 10069           True   4384131.0
# 12117           True  14271802.0
# 8410            True    522723.0

# %% [markdown]
#     - Contad cuantas canciones tiene cada artista utilizando el dataframe generado en el paso anterior.

# %%
df_artist_feat = df_feat.groupby('artist')['title'].count().reset_index()
df_artist_feat
# Out:
#             artist  title
# 0        070 Shake      1
# 1              112      4
# 2           1Nonly      1
# 3         2 Chainz      1
# 4        21 Savage      2
# ..             ...    ...
# 684   Zara Larsson      3
# 685           Zayn      1
# 686  Zion & Lennox      1
# 687           Ñejo      1
# 688     Ñengo Flow      1
#
# [689 rows x 2 columns]

# %% [markdown]
#     - Mostrad los resultados en una gráfica, seleccionado los 10 artistas con más colaboraciones.

# %%
mas_feat = df_artist_feat.sort_values('title', ascending = False).head(10)
mas_feat
# Out:
#                       artist  title
# 312                  Juicy J     10
# 398               Macklemore     10
# 647            Ty Dolla Sign      9
# 167                Dj Khaled      9
# 666             Wu-Tang Clan      9
# 399  Macklemore & Ryan Lewis      8
# 516                  Popcaan      8
# 125             Clean Bandit      8
# 412              Mark Ronson      8
# 656                     Wale      8

# %%
plt.figure(figsize = (8,5))

fig = sns.barplot(x = 'title', y = 'artist', data = mas_feat, palette = 'pastel', edgecolor = 'black')

plt.show()

# %% [markdown]
# Deberéis contestar a las siguientes preguntas:

# %% [markdown]
# - ¿Cuáles son los diez artistas que más han colaborado según los datos que tenemos?

# %%
artistas_colaboradores = ', '.join(mas_feat['artist'].unique())
print(f'Los 10 artistas que más colaboraciones han realizado han sido:\n{artistas_colaboradores}.')
# Out:
# Los 10 artistas que más colaboraciones han realizado han sido:
# Juicy J, Macklemore, Ty Dolla Sign, Dj Khaled, Wu-Tang Clan, Macklemore & Ryan Lewis, Popcaan, Clean Bandit, Mark Ronson, Wale.

# %% [markdown]
# - ¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el ranking?

# %%
artista_colaborador1 = mas_feat.iloc[0][0]
numero_colaboraciones1 = mas_feat.iloc[0][1]

artista_colaborador2 = mas_feat.iloc[1][0]
numero_colaboraciones2 = mas_feat.iloc[1][1]

# %%
print(f'Los artistas con más colaboraciones son {artista_colaborador1} y {artista_colaborador2}, ambos con un numero total de {numero_colaboraciones1} colaboraciones.')
# Out:
# Los artistas con más colaboraciones son Juicy J y Macklemore, ambos con un numero total de 10 colaboraciones.

# %% [markdown]
# - ¿Cuál es el artista que ocupa el décimo lugar en el ranking y en cuántas canciones ha colaborado?

# %%
artista10 = mas_feat.iloc[9][0]
colab10 = mas_feat.iloc[9][1]
print(f'En el decimo lugar se encuentra {artista10}, con un numero total de {colab10} colaboraciones.')
# Out:
# En el decimo lugar se encuentra Wale, con un numero total de 8 colaboraciones.

# %% [markdown]
# Utilizando el dataframe original, queremos explorar si el tipo de álbum influye en la cantidad de vistas que recibe en una plataforma de transmisión de música. Para ello, debemos generar un boxplot con las variables necesarias y responder las siguientes preguntas:

# %%
df.sample()
# Out:
#          artist                                        url_spotify      track  \
# 1002  Pearl Jam  https://open.spotify.com/artist/1w5Kfo2jwwIPru...  Last Kiss
#
#           album album_type                                   uri  \
# 1002  Last Kiss     single  spotify:track:0QnONzv3TvHAWk294h6DaQ
#
#       danceability  energy  key  loudness  speechiness  acousticness  \
# 1002         0.622   0.692  7.0     -6.97       0.0276         0.363
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 1002          0.000158     0.193    0.774  112.053     195467.0
#
#                                       url_youtube                title  \
# 1002  https://www.youtube.com/watch?v=uvjTo-hRD5c  Pearl Jam-Last Kiss
#
#            channel       views     likes  comments  \
# 1002  alostsoul316  16254331.0  131331.0    3513.0
#
#                          description licensed official_video       stream
# 1002  Video from High School Project    False          False  230392759.0

# %%
df['album_type'].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
fix,ax = plt.subplots(1,3, figsize = (20,5))

sns.boxplot(x = df_album['views'], ax=ax[0])
sns.boxplot(x = df_single['views'], ax=ax[1])
sns.boxplot(x = df_compilation['views'], ax=ax[2])

ax[0].set_title('Album')
ax[1].set_title('Single')
ax[2].set_title('Compilation')

plt.show()

# %%
df_type_views = df.groupby('album_type')['views'].sum().reset_index()
df_type_views
# Out:
#     album_type         views
# 0        album  1.438910e+12
# 1  compilation  6.122649e+10
# 2       single  4.019165e+11

# %%
# convertimos el numero de visitas a porcentaje
df_type_views['views'] = df_type_views['views']/df_type_views['views'].sum()

# %%
df_type_views
# Out:
#     album_type     views
# 0        album  0.756504
# 1  compilation  0.032190
# 2       single  0.211307

# %% [markdown]
# - ¿Qué tipo de álbumes tienden a tener más vistas en promedio?

# %% [markdown]
# >Tras convertir el numero de visitas a porcentaje comrpobamos que el tipo de album **sí** influye en el número de visitas, siendo los de tipo **album** los que más visitas reciben (más del 75%)

# %% [markdown]
# - ¿Hay algún tipo de álbumes que tenga una mayor dispersión en las vistas recibidas

# %%
df_album['views'].agg(['mean', 'median', 'std']).reset_index()
# Out:
#     index         views
# 0    mean  9.842739e+07
# 1  median  1.578171e+07
# 2     std  2.858933e+08

# %%
df_single['views'].agg(['mean', 'median', 'std']).reset_index()
# Out:
#     index         views
# 0    mean  8.269886e+07
# 1  median  1.132483e+07
# 2     std  2.461023e+08

# %%
df_compilation['views'].agg(['mean', 'median', 'std']).reset_index()
# Out:
#     index         views
# 0    mean  7.961832e+07
# 1  median  9.569629e+06
# 2     std  2.196741e+08

# %% [markdown]
# Al no poder ser posible hacer una interpretación a simple vista de la dispersión de los datos, optamos por extraer los coeficientes de variación de los datos para cada uno de los tipos de album:

# %%
album_coef = df_album['views'].std()/df_album['views'].mean()
single_coef = df_single['views'].std()/df_single['views'].mean()
compilation_coef = df_compilation['views'].std()/df_compilation['views'].mean()

# %%
print(album_coef)
print(single_coef)
print(compilation_coef)
# Out:
# 2.9046110131986675
# 2.9758853729281896
# 2.7590905327986115

# %% [markdown]
# Comprobamos que el coeficiente de dispersión no es muy elevado, econtrándose en los 3 casos.

# %% [markdown]
# - ¿Existen valores atípicos (outliers) en alguna categoría de álbumes?

# %% [markdown]
# Existen numerosos outliers en las tres categorías que desplazan la media hacia valores más altos, no siendo esta una medida robusta para ninguno de las tres categorías, pero especialmente para la de álbum, cuyos outliers alcanzan cifras muy elevadas por encima de la media en comparación con los otras dos categorías.

# %% [markdown]
# - ¿Qué conclusión se puede obtener sobre la relación entre el tipo de álbum y la cantidad de vistas recibidas?

# %%
df_album['views'].describe().reset_index().T
# Out:
#              0                1                 2    3          4           5  \
# index    count             mean               std  min        25%         50%
# views  14619.0  98427393.059648  285893289.881489  0.0  2052173.0  15781710.0
#
#                 6             7
# index         75%           max
# views  72642342.5  8079649362.0

# %%
df_single['views'].describe().reset_index().T
# Out:
#             0                1                 2     3           4  \
# index   count             mean               std   min         25%
# views  4860.0  82698859.343416  246102325.877916  28.0  1374965.25
#
#                 5            6             7
# index         50%          75%           max
# views  11324830.0  63286504.75  5773798407.0

# %%
df_compilation['views'].describe().reset_index().T
# Out:
#            0                1                 2     3         4          5  \
# index  count             mean               std   min       25%        50%
# views  769.0  79618318.282185  219674148.209722  71.0  656414.0  9569629.0
#
#                 6             7
# index         75%           max
# views  63125368.0  3463816330.0

# %% [markdown]
# En relación a nuestros datos podemos inferir que entre los tipos de álbum son los albumes los que reciben más visitas (alrededor de un 75%), seguidos de los singels y en último lugar las compilaciones.
